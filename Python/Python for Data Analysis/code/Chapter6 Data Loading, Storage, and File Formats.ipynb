# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/test.csv')

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
pd.read_table('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/test.csv',sep=',')
# Out:
# D:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# ...

# %%
data = pd.read_csv('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/test.csv',names=['a','b','c','d','e'])

# %%
names = ['a','b','c','d','e','message']

# %%
pd.read_csv('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/test.csv',names=names,index_col='message')
# Out:
#                    a       b                                 c       d     e
# message
# NaN      PassengerId  Pclass                              Name     Sex   Age
# NaN              892       3                  Kelly, Mr. James    male  34.5
# NaN              893       3  Wilkes, Mrs. James (Ellen Needs)  female    47
# NaN              894       2         Myles, Mr. Thomas Francis    male    62
# NaN              895       3                  Wirz, Mr. Albert    male    27

# %%
pd.isnull(data)
# Out:
#        a      b      c      d      e
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False   True  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
result = pd.read_csv('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/test.csv',na_values=['NULL'])

# %%
result
# Out:
#    PassengerId  Pclass                              Name     Sex   Age
# 0          892     3.0                  Kelly, Mr. James    male  34.5
# 1          893     NaN  Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2          894     2.0         Myles, Mr. Thomas Francis    male  62.0
# 3          895     3.0                  Wirz, Mr. Albert    male  27.0

# %%
setinels = {'Pclass':['3.0'],'Age':['34.5','47.0']}

# %%
pd.read_csv('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/test.csv',na_values=setinels)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age
# 0          892     3.0                  Kelly, Mr. James    male   NaN
# 1          893     NaN  Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2          894     2.0         Myles, Mr. Thomas Francis    male  62.0
# 3          895     3.0                  Wirz, Mr. Albert    male  27.0

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/train.csv')

# %%
result
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
result = pd.read_csv('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/train.csv',nrows=5)

# %%
result
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
chunker = pd.read_csv('F:/coding/Python/DataAnalysis/PythonForDataAnalysis/train.csv',chunksize=100)

# %%
chunker

# %%
tot = pd.Series([])
for piece in chunker:
    tot = tot.add(piece['PassengerId'].value_counts().fill_value=0)
    
tot =  tot.sort_values(ascending=False)
# Out:
#   File "<ipython-input-54-d13c1e4923ff>", line 3
#     tot = tot.add(piece['PassengerId'].value_counts().fill_value=0)
#                  ^
# SyntaxError: keyword can't be an expression

# %%
import sys

# %%
data.to_csv(sys.stdout,sep='|')
# Out:
# |a|b|c|d|e
# 0|PassengerId|Pclass|Name|Sex|Age
# 1|892|3|Kelly, Mr. James|male|34.5
# 2|893||Wilkes, Mrs. James (Ellen Needs)|female|47
# 3|894|2|Myles, Mr. Thomas Francis|male|62
# 4|895|3|Wirz, Mr. Albert|male|27

# %%
data.to_csv(sys.stdout,na_rep='NULL')
# Out:
# ,a,b,c,d,e
# 0,PassengerId,Pclass,Name,Sex,Age
# 1,892,3,"Kelly, Mr. James",male,34.5
# 2,893,NULL,"Wilkes, Mrs. James (Ellen Needs)",female,47
# 3,894,2,"Myles, Mr. Thomas Francis",male,62
# 4,895,3,"Wirz, Mr. Albert",male,27

# %%
dates = pd.date_range('1/1/2000',periods=7)

# %%
ts = pd.Series(np.arange(7),index=dates)

# %%
ts.to_csv('test.csv')
# Out:
# D:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
import csv

# %%
f = open('test.csv')

# %%
reader = csv.reader(f)

# %%
for line in reader:
    print(line)

# %%
with open('test.csv') as f:
    lines = list(csv.reader(f))

# %%
header,values = lines[0],lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}

# %%
data_dict
# Out:
# {'2000-01-01': ('2000-01-02',
#   '2000-01-03',
#   '2000-01-04',
#   '2000-01-05',
#   '2000-01-06',
#   '2000-01-07'),
#  '0': ('1', '2', '3', '4', '5', '6')}

# %%
import json

# %%
result = json.loads(obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-c4e84580859b> in <module>
# ----> 1 result = json.loads(obj)
#
# NameError: name 'obj' is not defined

# %%
import sqlite3

# %%
query = """
        CREATE TABLE test2
        (a VARCHER(20),b VARCHER(20),
         c REAL,    d INTEGER
         );"""

# %%
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)

# %%
con.commit()
